# %%
import pandas as pd
import os
import multiprocessing
import get_chdir_signatures
import re
import multiprocessing_logging
import logging

# %%
logger = logging.getLogger()
logger.setLevel(logging.INFO)
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')

# log를 파일에 출력
file_handler = logging.FileHandler('log.log')
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# %%
# %run get_chdir_signatures.py

# %%
folder = "../data/LINCS_CFDE/GSE92742_full_batches"
pred_folder = "../data/LINCS_CFDE/L1000_GSE92742_prediction_results_step2_batch_divided_38_35"
gene_filename = folder+"/GSE92742_genes.txt"
inst_filename = "../data/L1000/GSE92742_Broad_LINCS_inst_info.txt"
l1000_folder = "../data/LINCS_CFDE/GSE92742_full_batches"

output_folder = "../data/dexamethasone_v2"

# %%
# load gene index
with open(gene_filename, "r") as f:
    gene_list = [x.strip() for x in f.readlines()]

# %%
# load inst info
inst_info = pd.read_csv(inst_filename, sep="\t")


# generate experiment column
inst_info["batch"] = inst_info["rna_plate"].replace(to_replace='_X[0-9]', value='', regex=True)

# dexamethasone inst info
dexamethasone_inst_info = inst_info[inst_info["pert_iname"]=="dexamethasone"]

pert_ids = dexamethasone_inst_info["pert_id"].unique()
# Out:
# /home/maayanlab/anaconda3/envs/python37/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3170: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# get common genes
prediction_gene_filename = "../output_step2/35/logs/prediction_gene_list.txt"
with open(prediction_gene_filename, "r") as f:
    prediction_gene_list = [x.strip() for x in f.readlines()]

common_gene_list = list(set(gene_list).intersection(prediction_gene_list))

# %%
def chdir(batchfile):
    ''' 
    {batchfile} contains all Level 3 instances belonging to a single batch. 
    Compute all signatures in the batch via characteristic direction, by 
    comparing the perturbation replicate instances (cases) against all other 
    instances in the batch (controls). 
    '''

    # ignore this pesky file
    if batchfile == '.DS_Store':
        return None
    
    
    batch = batchfile.replace(".f", "")
    sig_df = inst_info[inst_info['batch'] == batch]
    
    signatures_list = list()
    signatures_list_l1000 = list()
    processed_pert_list = list()
    if sig_df.shape[0] == 0:
        logger.info("Passed: "+batchfile)
        return None
    else:
        batch_data_df = load_feather(f"{pred_folder}/{batchfile}", None)
        batch_data_df = batch_data_df[common_gene_list]

        batch_data_df_l1000 = load_feather(f"{l1000_folder}/{batchfile}", gene_list).T
        batch_data_df_l1000 = batch_data_df_l1000[common_gene_list]

        batch_pert_ids = sig_df["pert_id"].unique()
        for batch_pert_id in batch_pert_ids:
            if pert_ids is not None:
                if batch_pert_id not in pert_ids:
                    
                    continue
            logger.info(batch_pert_id+"in"+batchfile) 

            # single pert_id is case
            control_inst_id = sig_df.loc[sig_df["pert_id"]!=batch_pert_id, "inst_id"].tolist()
            case_inst_id = sig_df.loc[sig_df["pert_id"]==batch_pert_id, "inst_id"].tolist()

            control_gex_data_df = batch_data_df.loc[control_inst_id, :]
            case_gex_data_df = batch_data_df.loc[case_inst_id, :]
            signature = get_signatures(control_gex_data_df.T, case_gex_data_df.T)
            signatures_list.append(signature)

            control_gex_data_df_l1000 = batch_data_df_l1000.loc[control_inst_id, :]
            case_gex_data_df_l1000 = batch_data_df_l1000.loc[case_inst_id, :]
            signature_l1000 = get_signatures(control_gex_data_df_l1000.T, case_gex_data_df_l1000.T)
            signatures_list_l1000.append(signature_l1000)

            processed_pert_list.append(batch_pert_id)
            # break
    if len(signatures_list) > 0:
        signature_df = pd.concat(signatures_list, axis=1)
        signature_df.columns = processed_pert_list

        signature_df_l1000 = pd.concat(signatures_list_l1000, axis=1)
        signature_df_l1000.columns = processed_pert_list

        # save signature_df 
        signature_df.to_csv(f"{output_folder}/predicted_rnaseq_signature_{batch}.csv")
        signature_df_l1000.to_csv(f"{output_folder}/l1000_signature_{batch}.csv")
        logger.info(f"Saved!{output_folder}/predicted_rnaseq_signature_{batch}.csv")
        logger.info(f"Saved!{output_folder}/l1000_signature_{batch}.csv")
    # return signature_df

# %%
# example
chdir("CPC004_A375_6H.f")
# Out:
# INFO:root:BRD-A10188456inCPC004_A375_6H.f
# 2021-06-10 00:21:12,813 - root - INFO - BRD-A10188456inCPC004_A375_6H.f
# 2021-06-10 00:21:12,813 - root - INFO - BRD-A10188456inCPC004_A375_6H.f
# INFO:root:BRD-K47635719inCPC004_A375_6H.f
# 2021-06-10 00:21:22,880 - root - INFO - BRD-K47635719inCPC004_A375_6H.f
# 2021-06-10 00:21:22,880 - root - INFO - BRD-K47635719inCPC004_A375_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC004_A375_6H.csv
# 2021-06-10 00:21:32,923 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC004_A375_6H.csv
# 2021-06-10 00:21:32,923 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC004_A375_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC004_A375_6H.csv
# 2021-06-10 00:21:32,925 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC004_A375_6H.csv
# 2021-06-10 00:21:32,925 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC004_A375_6H.csv
#         BRD-A10188456  BRD-K47635719
# CXCL8        0.076309       0.023644
# HOXA10       0.062403      -0.014514
# CXCL2        0.053610       0.024308
# CXCL1        0.048457       0.035831
# PPEF2        0.046383      -0.006764
# ...               ...            ...
# ZNF302      -0.040048      -0.003634
# EPHB2       -0.042114      -0.036061
# COL4A1      -0.056763       0.007695
# MEST        -0.066673       0.061537
# IGFBP3      -0.068388       0.018022
#
# [11833 rows x 2 columns]

# %%
for batchfile in batchfiles:
    chdir(batchfile)
# Out:
# INFO:root:BRD-K38775274inCPC020_HCC515_6H.f
# 2021-06-10 00:29:58,439 - root - INFO - BRD-K38775274inCPC020_HCC515_6H.f
# 2021-06-10 00:29:58,439 - root - INFO - BRD-K38775274inCPC020_HCC515_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC020_HCC515_6H.csv
# 2021-06-10 00:30:03,401 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC020_HCC515_6H.csv
# 2021-06-10 00:30:03,401 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC020_HCC515_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC020_HCC515_6H.csv
# 2021-06-10 00:30:03,403 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC020_HCC515_6H.csv
# 2021-06-10 00:30:03,403 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC020_HCC515_6H.csv
# INFO:root:BRD-A10188456inCPC004_HCC515_24H.f
# 2021-06-10 00:30:18,856 - root - INFO - BRD-A10188456inCPC004_HCC515_24H.f
# 2021-06-10 00:30:18,856 - root - INFO - BRD-A10188456inCPC004_HCC515_24H.f
# INFO:root:BRD-K47635719inCPC004_HCC515_24H.f
# 2021-06-10 00:30:28,833 - root - INFO - BRD-K47635719inCPC004_HCC515_24H.f
# 2021-06-10 00:30:28,833 - root - INFO - BRD-K47635719inCPC004_HCC515_24H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC004_HCC515_24H.csv
# 2021-06-10 00:30:38,668 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC004_HCC515_24H.csv
# 2021-06-10 00:30:38,668 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC004_HCC515_24H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC004_HCC515_24H.csv
# 2021-06-10 00:30:38,670 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC004_HCC515_24H.csv
# 2021-06-10 00:30:38,670 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC004_HCC515
6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC004_HCC515_6H.csv
# 2021-06-10 00:32:09,445 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC004_HCC515_6H.csv
# 2021-06-10 00:32:09,445 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC004_HCC515_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC004_HCC515_6H.csv
# 2021-06-10 00:32:09,446 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC004_HCC515_6H.csv
# 2021-06-10 00:32:09,446 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC004_HCC515_6H.csv
# INFO:root:BRD-A10188456inCPC017_NPC_24H.f
# 2021-06-10 00:32:10,202 - root - INFO - BRD-A10188456inCPC017_NPC_24H.f
# 2021-06-10 00:32:10,202 - root - INFO - BRD-A10188456inCPC017_NPC_24H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC017_NPC_24H.csv
# 2021-06-10 00:32:25,668 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC017_NPC_24H.csv
# 2021-06-10 00:32:25,668 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC017_NPC_24H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC017_NPC_24H.csv
# 2021-06-10 00:32:25,670 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC017_NPC_24H.csv
# 2021-06-10 00:32:25,670 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC017_NPC_24H.csv
# INFO:root:BRD-A35108200inCPC006_HT115_6H.f
# 2021-06-10 00:32:29,103 - root - INFO - BRD-A35108200inCPC006_HT115_6H.f
# 2021-06-10 00:32:29,103 - root - INFO - BRD-A35108200inCPC006_HT115_6H.f
# INFO:root:BRD-A69951442inCPC006_HT115_6H.f
# 2021-06-10 00:32:33,339 - root - INFO - BRD-A69951442inCPC006_HT115_6H.f
# 2021-06-10 00:32:33,339 - root - INFO - BRD-A69951442inCPC006_HT115_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_HT115_6H.csv
# 2021-06-10 00:32:37,658 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_HT115_6H.csv
# 2021-06-10 00:32:37,658 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_HT115_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC006_HT115_6H.csv
# 2021-06-10 00:32:37,660 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_HT115_6H.csv
# 2021-06-10 00:32:37,660 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_HT115_6H.csv
# INFO:root:BRD-A35108200inCPC006_HEC108_6H.f
# 2021-06-10 00:32:42,371 - root - INFO - BRD-A35108200inCPC006_HEC108_6H.f
# 2021-06-10 00:32:42,371 - root - INFO - BRD-A35108200inCPC006_HEC108_6H.f
# INFO:root:BRD-A69951442inCPC006_HEC108_6H.f
# 2021-06-10 00:32:52,343 - root - INFO - BRD-A69951442inCPC006_HEC108_6H.f
# 2021-06-10 00:32:52,343 - root - INFO - BRD-A69951442inCPC006_HEC108_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_HEC108_6H.csv
# 2021-06-10 00:33:02,303 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_HEC108_6H.csv
# 2021-06-10 00:33:02,303 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_HEC108_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC006_HEC108_6H.csv
# 2021-06-10 00:33:02,305 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_HEC108_6H.csv
# 2021-06-10 00:33:02,305 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_HEC108_6H.csv
# INFO:root:BRD-A10188456inCPC004_HEPG2_6H.f
# 2021-06-10 00:33:04,776 - root - INFO - BRD-A10188456inCPC004_HEPG2_6H.f
# 2021-06-10 00:33:04,776 - root - INFO - BRD-A10188456inCPC004_HEPG2_6H.f
# INFO:root:BRD-K47635719inCPC004_HEPG2_6H.f
# 2021-06-10 00:33:09,614 - root - INFO - BRD-K47635719inCPC004_HEPG2_6H.f
# 2021-06-10 00:33:09,614 - root - INFO - BRD-K47635719inCPC004_HEPG2_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC004_HEPG2_6H.csv
# 2021-06-10 00:33:14,523 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC004_HEPG2_6H.csv
# 2021-06-10 00:33:14,523 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC004_HEPG2_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC004_HEPG2_6H.csv
# 2021-06-10 00:33:14,525 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC004_HEPG2_6H.csv
# 2021-06-10 00:33:14,525 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC004_HEPG2_6H.csv
# INFO:root:BRD-A35108200inCPC006_MCF7_6H.f
# 2021-06-10 00:33:20,216 - root - INFO - BRD-A35108200inCPC006_MCF7_6H.f
# 2021-06-10 00:33:20,216 - root - INFO - BRD-A35108200inCPC006_MCF7_6H.f
# INFO:root:BRD-A69951442inCPC006_MCF7_6H.f
# 2021-06-10 00:33:45,479 - root - INFO - BRD-A69951442inCPC006_MCF7_6H.f
# 2021-06-10 00:33:45,479 - root - INFO - BRD-A69951442inCPC006_MCF7_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_MCF7_6H.csv
# 2021-06-10 00:34:10,668 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_MCF7_6H.csv
# 2021-06-10 00:34:10,668 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_MCF7_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC006_MCF7_6H.csv
# 2021-06-10 00:34:10,670 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_MCF7_6H.csv
# 2021-06-10 00:34:10,670 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_MCF7_6H.csv
# INFO:root:BRD-A35108200inCPC006_VCAP_24H.f
# 2021-06-10 00:34:12,658 - root - INFO - BRD-A35108200inCPC006_VCAP_24H.f
# 2021-06-10 00:34:12,658 - root - INFO - BRD-A35108200inCPC006_VCAP_24H.f
# INFO:root:BRD-A69951442inCPC006_VCAP_24H.f
# 2021-06-10 00:34:36,901 - root - INFO - BRD-A69951442inCPC006_VCAP_24H.f
# 2021-06-10 00:34:36,901 - root - INFO - BRD-A69951442inCPC006_VCAP_24H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_VCAP_24H.csv
# 2021-06-10 00:35:01,050 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_VCAP_24H.csv
# 2021-06-10 00:35:01,050 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_VCAP_24H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC006_VCAP_24H.csv
# 2021-06-10 00:35:01,051 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_VCAP_24H.csv
# 2021-06-10 00:35:01,051 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_VCAP_24H.csv
# INFO:root:BRD-K38775274inCPC014_PC3_6H.f
# 2021-06-10 00:35:03,878 - root - INFO - BRD-K38775274inCPC014_PC3_6H.f
# 2021-06-10 00:35:03,878 - root - INFO - BRD-K38775274inCPC014_PC3_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC014_PC3_6H.csv
# 2021-06-10 00:35:20,107 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC014_PC3_6H.csv
# 2021-06-10 00:35:20,107 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC014_PC3_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC014_PC3_6H.csv
# 2021-06-10 00:35:20,108 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC014_PC3_6H.csv
# 2021-06-10 00:35:20,108 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC014_PC3_6H.csv
# INFO:root:BRD-A35108200inCPC006_VCAP_6H.f
# 2021-06-10 00:35:34,032 - root - INFO - BRD-A35108200inCPC006_VCAP_6H.f
# 2021-06-10 00:35:34,032 - root - INFO - BRD-A35108200inCPC006_VCAP_6H.f
# INFO:root:BRD-A69951442inCPC006_VCAP_6H.f
# 2021-06-10 00:35:51,303 - root - INFO - BRD-A69951442inCPC006_VCAP_6H.f
# 2021-06-10 00:35:51,303 - root - INFO - BRD-A69951442inCPC006_VCAP_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_VCAP_6H.csv
# 2021-06-10 00:36:08,189 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_VCAP_6H.csv
# 2021-06-10 00:36:08,189 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_VCAP_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC006_VCAP_6H.csv
# 2021-06-10 00:36:08,191 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_VCAP_6H.csv
# 2021-06-10 00:36:08,191 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_VCAP_6H.csv
# INFO:root:BRD-K38775274inCPC014_A549_6H.f
# 2021-06-10 00:36:40,140 - root - INFO - BRD-K38775274inCPC014_A549_6H.f
# 2021-06-10 00:36:40,140 - root - INFO - BRD-K38775274inCPC014_A549_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC014_A549_6H.csv
# 2021-06-10 00:36:50,430 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC014_A549_6H.csv
# 2021-06-10 00:36:50,430 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC014_A549_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC014_A549_6H.csv
# 2021-06-10 00:36:50,431 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC014_A549_6H.csv
# 2021-06-10 00:36:50,431 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC014_A549_6H.csv
# INFO:root:BRD-A10188456inCPC004_VCAP_24H.f
# 2021-06-10 00:36:57,038 - root - INFO - BRD-A10188456inCPC004_VCAP_24H.f
# 2021-06-10 00:36:57,038 - root - INFO - BRD-A10188456inCPC004_VCAP_24H.f
# INFO:root:BRD-K47635719inCPC004_VCAP_24H.f
# 2021-06-10 00:37:21,337 - root - INFO - BRD-K47635719inCPC004_VCAP_24H.f
# 2021-06-10 00:37:21,337 - root - INFO - BRD-K47635719inCPC004_VCAP_24H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC004_VCAP_24H.csv
# 2021-06-10 00:37:45,659 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC004_VCAP_24H.csv
# 2021-06-10 00:37:45,659 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC004_VCAP_24H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC004_VCAP_24H.csv
# 2021-06-10 00:37:45,660 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC004_VCAP_24H.csv
# 2021-06-10 00:37:45,660 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC004_VCAP_24H.csv
# INFO:root:BRD-A35108200inCPC009_HEPG2_6H.f
# 2021-06-10 00:37:47,928 - root - INFO - BRD-A35108200inCPC009_HEPG2_6H.f
# 2021-06-10 00:37:47,928 - root - INFO - BRD-A35108200inCPC009_HEPG2_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC009_HEPG2_6H.csv
# 2021-06-10 00:37:57,890 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC009_HEPG2_6H.csv
# 2021-06-10 00:37:57,890 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC009_HEPG2_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC009_HEPG2_6H.csv
# 2021-06-10 00:37:57,891 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC009_HEPG2_6H.csv
# 2021-06-10 00:37:57,891 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC009_HEPG2_6H.csv
# INFO:root:BRD-K38775274inCPC014_MCF7_24H.f
# 2021-06-10 00:38:11,950 - root - INFO - BRD-K38775274inCPC014_MCF7_24H.f
# 2021-06-10 00:38:11,950 - root - INFO - BRD-K38775274inCPC014_MCF7_24H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC014_MCF7_24H.csv
# 2021-06-10 00:38:21,281 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC014_MCF7_24H.csv
# 2021-06-10 00:38:21,281 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC014_MCF7_24H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC014_MCF7_24H.csv
# 2021-06-10 00:38:21,283 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC014_MCF7_24H.csv
# 2021-06-10 00:38:21,283 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC014_MCF7_24H.csv
# INFO:root:BRD-A35108200inCPC006_RKO_6H.f
# 2021-06-10 00:38:22,573 - root - INFO - BRD-A35108200inCPC006_RKO_6H.f
# 2021-06-10 00:38:22,573 - root - INFO - BRD-A35108200inCPC006_RKO_6H.f
# INFO:root:BRD-A69951442inCPC006_RKO_6H.f
# 2021-06-10 00:38:27,360 - root - INFO - BRD-A69951442inCPC006_RKO_6H.f
# 2021-06-10 00:38:27,360 - root - INFO - BRD-A69951442inCPC006_RKO_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_RKO_6H.csv
# 2021-06-10 00:38:32,224 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_RKO_6H.csv
# 2021-06-10 00:38:32,224 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_RKO_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC006_RKO_6H.csv
# 2021-06-10 00:38:32,226 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_RKO_6H.csv
# 2021-06-10 00:38:32,226 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_RKO_6H.csv
# INFO:root:BRD-A35108200inCPC009_VCAP_24H.f
# 2021-06-10 00:38:33,833 - root - INFO - BRD-A35108200inCPC009_VCAP_24H.f
# 2021-06-10 00:38:33,833 - root - INFO - BRD-A35108200inCPC009_VCAP_24H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC009_VCAP_24H.csv
# 2021-06-10 00:38:50,200 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC009_VCAP_24H.csv
# 2021-06-10 00:38:50,200 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC009_VCAP_24H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC009_VCAP_24H.csv
# 2021-06-10 00:38:50,202 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC009_VCAP_24H.csv
# 2021-06-10 00:38:50,202 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC009
24H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC009_MCF7_24H.csv
# 2021-06-10 00:40:28,859 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC009_MCF7_24H.csv
# 2021-06-10 00:40:28,859 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC009_MCF7_24H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC009_MCF7_24H.csv
# 2021-06-10 00:40:28,861 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC009_MCF7_24H.csv
# 2021-06-10 00:40:28,861 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC009_MCF7_24H.csv
# INFO:root:BRD-A35108200inCPC006_NCIH2073_6H.f
# 2021-06-10 00:40:35,848 - root - INFO - BRD-A35108200inCPC006_NCIH2073_6H.f
# 2021-06-10 00:40:35,848 - root - INFO - BRD-A35108200inCPC006_NCIH2073_6H.f
# INFO:root:BRD-A69951442inCPC006_NCIH2073_6H.f
# 2021-06-10 00:40:40,681 - root - INFO - BRD-A69951442inCPC006_NCIH2073_6H.f
# 2021-06-10 00:40:40,681 - root - INFO - BRD-A69951442inCPC006_NCIH2073_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_NCIH2073_6H.csv
# 2021-06-10 00:40:45,604 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_NCIH2073_6H.csv
# 2021-06-10 00:40:45,604 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_NCIH2073_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC006_NCIH2073_6H.csv
# 2021-06-10 00:40:45,605 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_NCIH2073_6H.csv
# 2021-06-10 00:40:45,605 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_NCIH2073_6H.csv
# INFO:root:BRD-A35108200inCPC006_T3M10_6H.f
# 2021-06-10 00:40:47,366 - root - INFO - BRD-A35108200inCPC006_T3M10_6H.f
# 2021-06-10 00:40:47,366 - root - INFO - BRD-A35108200inCPC006_T3M10_6H.f
# INFO:root:BRD-A69951442inCPC006_T3M10_6H.f
# 2021-06-10 00:40:51,436 - root - INFO - BRD-A69951442inCPC006_T3M10_6H.f
# 2021-06-10 00:40:51,436 - root - INFO - BRD-A69951442inCPC006_T3M10_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_T3M10_6H.csv
# 2021-06-10 00:40:55,517 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_T3M10_6H.csv
# 2021-06-10 00:40:55,517 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_T3M10_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC006_T3M10_6H.csv
# 2021-06-10 00:40:55,519 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_T3M10_6H.csv
# 2021-06-10 00:40:55,519 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_T3M10_6H.csv
# INFO:root:BRD-A35108200inCPC006_U937_6H.f
# 2021-06-10 00:40:57,981 - root - INFO - BRD-A35108200inCPC006_U937_6H.f
# 2021-06-10 00:40:57,981 - root - INFO - BRD-A35108200inCPC006_U937_6H.f
# INFO:root:BRD-A69951442inCPC006_U937_6H.f
# 2021-06-10 00:41:02,632 - root - INFO - BRD-A69951442inCPC006_U937_6H.f
# 2021-06-10 00:41:02,632 - root - INFO - BRD-A69951442inCPC006_U937_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_U937_6H.csv
# 2021-06-10 00:41:07,415 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_U937_6H.csv
# 2021-06-10 00:41:07,415 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_U937_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC006_U937_6H.csv
# 2021-06-10 00:41:07,416 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_U937_6H.csv
# 2021-06-10 00:41:07,416 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_U937_6H.csv
# INFO:root:BRD-A35108200inCPC006_MDST8_6H.f
# 2021-06-10 00:41:08,159 - root - INFO - BRD-A35108200inCPC006_MDST8_6H.f
# 2021-06-10 00:41:08,159 - root - INFO - BRD-A35108200inCPC006_MDST8_6H.f
# INFO:root:BRD-A69951442inCPC006_MDST8_6H.f
# 2021-06-10 00:41:13,131 - root - INFO - BRD-A69951442inCPC006_MDST8_6H.f
# 2021-06-10 00:41:13,131 - root - INFO - BRD-A69951442inCPC006_MDST8_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_MDST8_6H.csv
# 2021-06-10 00:41:18,068 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_MDST8_6H.csv
# 2021-06-10 00:41:18,068 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_MDST8_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC006_MDST8_6H.csv
# 2021-06-10 00:41:18,070 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_MDST8_6H.csv
# 2021-06-10 00:41:18,070 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_MDST8_6H.csv
# INFO:root:BRD-A35108200inCPC009_A375_6H.f
# 2021-06-10 00:41:26,808 - root - INFO - BRD-A35108200inCPC009_A375_6H.f
# 2021-06-10 00:41:26,808 - root - INFO - BRD-A35108200inCPC009_A375_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC009_A375_6H.csv
# 2021-06-10 00:41:43,384 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC009_A375_6H.csv
# 2021-06-10 00:41:43,384 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC009_A375_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC009_A375_6H.csv
# 2021-06-10 00:41:43,385 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC009_A375_6H.csv
# 2021-06-10 00:41:43,385 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC009_A375_6H.csv
# INFO:root:BRD-A35108200inCPC006_RMUGS_6H.f
# 2021-06-10 00:41:49,866 - root - INFO - BRD-A35108200inCPC006_RMUGS_6H.f
# 2021-06-10 00:41:49,866 - root - INFO - BRD-A35108200inCPC006_RMUGS_6H.f
# INFO:root:BRD-A69951442inCPC006_RMUGS_6H.f
# 2021-06-10 00:41:58,783 - root - INFO - BRD-A69951442inCPC006_RMUGS_6H.f
# 2021-06-10 00:41:58,783 - root - INFO - BRD-A69951442inCPC006_RMUGS_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_RMUGS_6H.csv
# 2021-06-10 00:42:07,942 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_RMUGS_6H.csv
# 2021-06-10 00:42:07,942 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_RMUGS_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC006_RMUGS_6H.csv
# 2021-06-10 00:42:07,944 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_RMUGS_6H.csv
# 2021-06-10 00:42:07,944 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_RMUGS_6H.csv
# INFO:root:BRD-A35108200inCPC006_TYKNU_6H.f
# 2021-06-10 00:42:16,661 - root - INFO - BRD-A35108200inCPC006_TYKNU_6H.f
# 2021-06-10 00:42:16,661 - root - INFO - BRD-A35108200inCPC006_TYKNU_6H.f
# INFO:root:BRD-A69951442inCPC006_TYKNU_6H.f
# 2021-06-10 00:42:21,012 - root - INFO - BRD-A69951442inCPC006_TYKNU_6H.f
# 2021-06-10 00:42:21,012 - root - INFO - BRD-A69951442inCPC006_TYKNU_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_TYKNU_6H.csv
# 2021-06-10 00:42:25,533 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_TYKNU_6H.csv
# 2021-06-10 00:42:25,533 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_TYKNU_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC006_TYKNU_6H.csv
# 2021-06-10 00:42:25,535 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_TYKNU_6H.csv
# 2021-06-10 00:42:25,535 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_TYKNU_6H.csv
# INFO:root:BRD-A35108200inCPC006_THP1_6H.f
# 2021-06-10 00:42:36,607 - root - INFO - BRD-A35108200inCPC006_THP1_6H.f
# 2021-06-10 00:42:36,607 - root - INFO - BRD-A35108200inCPC006_THP1_6H.f
# INFO:root:BRD-A69951442inCPC006_THP1_6H.f
# 2021-06-10 00:42:44,464 - root - INFO - BRD-A69951442inCPC006_THP1_6H.f
# 2021-06-10 00:42:44,464 - root - INFO - BRD-A69951442inCPC006_THP1_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_THP1_6H.csv
# 2021-06-10 00:42:52,138 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_THP1_6H.csv
# 2021-06-10 00:42:52,138 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_THP1_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC006_THP1_6H.csv
# 2021-06-10 00:42:52,139 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_THP1_6H.csv
# 2021-06-10 00:42:52,139 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_THP1_6H.csv
# INFO:root:BRD-A35108200inCPC006_H1299_6H.f
# 2021-06-10 00:42:58,810 - root - INFO - BRD-A35108200inCPC006_H1299_6H.f
# 2021-06-10 00:42:58,810 - root - INFO - BRD-A35108200inCPC006_H1299_6H.f
# INFO:root:BRD-A69951442inCPC006_H1299_6H.f
# 2021-06-10 00:43:03,525 - root - INFO - BRD-A69951442inCPC006_H1299_6H.f
# 2021-06-10 00:43:03,525 - root - INFO - BRD-A69951442inCPC006_H1299_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_H1299_6H.csv
# 2021-06-10 00:43:08,342 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_H1299_6H.csv
# 2021-06-10 00:43:08,342 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_H1299_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC006_H1299_6H.csv
# 2021-06-10 00:43:08,343 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_H1299_6H.csv
# 2021-06-10 00:43:08,343 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_H1299_6H.csv
# INFO:root:Passed: LJP004_MDAMB231_24H.f
# 2021-06-10 00:43:11,107 - root - INFO - Passed: LJP004_MDAMB231_24H.f
# 2021-06-10 00:43:11,107 - root - INFO - Passed: LJP004_MDAMB231_24H.f
# INFO:root:BRD-K38775274inCPC014_VCAP_6H.f
# 2021-06-10 00:43:15,510 - root - INFO - BRD-K38775274inCPC014_VCAP_6H.f
# 2021-06-10 00:43:15,510 - root - INFO - BRD-K38775274inCPC014_VCAP_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC014_VCAP_6H.csv
# 2021-06-10 00:43:39,933 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC014_VCAP_6H.csv
# 2021-06-10 00:43:39,933 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC014_VCAP_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC014_VCAP_6H.csv
# 2021-06-10 00:43:39,934 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC014_VCAP_6H.csv
# 2021-06-10 00:43:39,934 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC014_VCAP_6H.csv
# INFO:root:BRD-A35108200inCPC006_PC3_24H.f
# 2021-06-10 00:43:41,256 - root - INFO - BRD-A35108200inCPC006_PC3_24H.f
# 2021-06-10 00:43:41,256 - root - INFO - BRD-A35108200inCPC006_PC3_24H.f
# INFO:root:BRD-A69951442inCPC006_PC3_24H.f
# 2021-06-10 00:44:17,894 - root - INFO - BRD-A69951442inCPC006_PC3_24H.f
# 2021-06-10 00:44:17,894 - root - INFO - BRD-A69951442inCPC006_PC3_24H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_PC3_24H.csv
# 2021-06-10 00:44:53,329 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_PC3_24H.csv
# 2021-06-10 00:44:53,329 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_PC3_24H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC006_PC3_24H.csv
# 2021-06-10 00:44:53,331 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_PC3_24H.csv
# 2021-06-10 00:44:53,331 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_PC3_24H.csv
# INFO:root:BRD-K38775274inNMH002_NPC_6H.f
# 2021-06-10 00:44:55,066 - root - INFO - BRD-K38775274inNMH002_NPC_6H.f
# 2021-06-10 00:44:55,066 - root - INFO - BRD-K38775274inNMH002_NPC_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_NMH002_NPC_6H.csv
# 2021-06-10 00:45:04,736 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_NMH002_NPC_6H.csv
# 2021-06-10 00:45:04,736 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_NMH002_NPC_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_NMH002_NPC_6H.csv
# 2021-06-10 00:45:04,738 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_NMH002_NPC_6H.csv
# 2021-06-10 00:45:04,738 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_NMH002_NPC_6H.csv
# INFO:root:BRD-A35108200inCPC006_PL21_6H.f
# 2021-06-10 00:45:05,492 - root - INFO - BRD-A35108200inCPC006_PL21_6H.f
# 2021-06-10 00:45:05,492 - root - INFO - BRD-A35108200inCPC006_PL21_6H.f
# INFO:root:BRD-A69951442inCPC006_PL21_6H.f
# 2021-06-10 00:45:10,257 - root - INFO - BRD-A69951442inCPC006_PL21_6H.f
# 2021-06-10 00:45:10,257 - root - INFO - BRD-A69951442inCPC006_PL21_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_PL21_6H.csv
# 2021-06-10 00:45:14,972 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_
6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_CORL23_6H.csv
# 2021-06-10 00:50:03,542 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_CORL23_6H.csv
# 2021-06-10 00:50:03,542 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_CORL23_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC006_CORL23_6H.csv
# 2021-06-10 00:50:03,543 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_CORL23_6H.csv
# 2021-06-10 00:50:03,543 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_CORL23_6H.csv
# INFO:root:BRD-A35108200inCPC006_WSUDLCL2_6H.f
# 2021-06-10 00:50:04,307 - root - INFO - BRD-A35108200inCPC006_WSUDLCL2_6H.f
# 2021-06-10 00:50:04,307 - root - INFO - BRD-A35108200inCPC006_WSUDLCL2_6H.f
# INFO:root:BRD-A69951442inCPC006_WSUDLCL2_6H.f
# 2021-06-10 00:50:08,662 - root - INFO - BRD-A69951442inCPC006_WSUDLCL2_6H.f
# 2021-06-10 00:50:08,662 - root - INFO - BRD-A69951442inCPC006_WSUDLCL2_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_WSUDLCL2_6H.csv
# 2021-06-10 00:50:13,172 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_WSUDLCL2_6H.csv
# 2021-06-10 00:50:13,172 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_WSUDLCL2_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC006_WSUDLCL2_6H.csv
# 2021-06-10 00:50:13,173 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_WSUDLCL2_6H.csv
# 2021-06-10 00:50:13,173 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_WSUDLCL2_6H.csv
# INFO:root:Passed: LJP004_BT20_1H.f
# 2021-06-10 00:50:14,692 - root - INFO - Passed: LJP004_BT20_1H.f
# 2021-06-10 00:50:14,692 - root - INFO - Passed: LJP004_BT20_1H.f
# INFO:root:BRD-A35108200inCPC006_SW480_6H.f
# 2021-06-10 00:50:16,311 - root - INFO - BRD-A35108200inCPC006_SW480_6H.f
# 2021-06-10 00:50:16,311 - root - INFO - BRD-A35108200inCPC006_SW480_6H.f
# INFO:root:BRD-A69951442inCPC006_SW480_6H.f
# 2021-06-10 00:50:21,190 - root - INFO - BRD-A69951442inCPC006_SW480_6H.f
# 2021-06-10 00:50:21,190 - root - INFO - BRD-A69951442inCPC006_SW480_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_SW480_6H.csv
# 2021-06-10 00:50:26,188 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_SW480_6H.csv
# 2021-06-10 00:50:26,188 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_SW480_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC006_SW480_6H.csv
# 2021-06-10 00:50:26,190 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_SW480_6H.csv
# 2021-06-10 00:50:26,190 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_SW480_6H.csv
# INFO:root:Passed: LJP004_HS578T_6H.f
# 2021-06-10 00:50:28,784 - root - INFO - Passed: LJP004_HS578T_6H.f
# 2021-06-10 00:50:28,784 - root - INFO - Passed: LJP004_HS578T_6H.f
# INFO:root:BRD-K47635719inCPC015_HT29_6H.f
# 2021-06-10 00:50:29,677 - root - INFO - BRD-K47635719inCPC015_HT29_6H.f
# 2021-06-10 00:50:29,677 - root - INFO - BRD-K47635719inCPC015_HT29_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC015_HT29_6H.csv
# 2021-06-10 00:50:39,592 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC015_HT29_6H.csv
# ...
# 2021-06-10 01:25:34,314 - root - INFO - BRD-A10188456inCPC017_ASC_24H.f
# 2021-06-10 01:25:34,314 - root - INFO - BRD-A10188456inCPC017_ASC_24H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC017_ASC_24H.csv
# 2021-06-10 01:25:50,212 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC017
6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_SW620_6H.csv
# 2021-06-10 01:27:48,994 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_SW620_6H.csv
# 2021-06-10 01:27:48,994 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_SW620_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC006_SW620_6H.csv
# 2021-06-10 01:27:48,995 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_SW620_6H.csv
# 2021-06-10 01:27:48,995 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_SW620_6H.csv
# INFO:root:Passed: T2D001_MCH58_144H.f
# 2021-06-10 01:27:49,880 - root - INFO - Passed: T2D001_MCH58_144H.f
# 2021-06-10 01:27:49,880 - root - INFO - Passed: T2D001_MCH58_144H.f
# INFO:root:BRD-K30207000inCPD001_MCF7_6H.f
# 2021-06-10 01:28:02,607 - root - INFO - BRD-K30207000inCPD001_MCF7_6H.f
# 2021-06-10 01:28:02,607 - root - INFO - BRD-K30207000inCPD001_MCF7_6H.f
# INFO:root:BRD-K00835182inCPD001_MCF7_6H.f
# 2021-06-10 01:28:12,991 - root - INFO - BRD-K00835182inCPD001_MCF7_6H.f
# 2021-06-10 01:28:12,991 - root - INFO - BRD-K00835182inCPD001_MCF7_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPD001_MCF7_6H.csv
# 2021-06-10 01:28:23,088 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPD001_MCF7_6H.csv
# 2021-06-10 01:28:23,088 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPD001_MCF7_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPD001_MCF7_6H.csv
# 2021-06-10 01:28:23,089 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPD001_MCF7_6H.csv
# 2021-06-10 01:28:23,089 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPD001_MCF7_6H.csv
# INFO:root:BRD-A35108200inCPC006_A673_6H.f
# 2021-06-10 01:28:28,300 - root - INFO - BRD-A35108200inCPC006_A673_6H.f
# 2021-06-10 01:28:28,300 - root - INFO - BRD-A35108200inCPC006_A673_6H.f
# INFO:root:BRD-A69951442inCPC006_A673_6H.f
# 2021-06-10 01:28:33,209 - root - INFO - BRD-A69951442inCPC006_A673_6H.f
# 2021-06-10 01:28:33,209 - root - INFO - BRD-A69951442inCPC006_A673_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_A673_6H.csv
# 2021-06-10 01:28:38,204 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_A673_6H.csv
# 2021-06-10 01:28:38,204 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_A673_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC006_A673_6H.csv
# 2021-06-10 01:28:38,205 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_A673_6H.csv
# 2021-06-10 01:28:38,205 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_A673_6H.csv
# INFO:root:BRD-K38775274inCPC020_VCAP_24H.f
# 2021-06-10 01:28:48,711 - root - INFO - BRD-K38775274inCPC020_VCAP_24H.f
# 2021-06-10 01:28:48,711 - root - INFO - BRD-K38775274inCPC020_VCAP_24H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC020_VCAP_24H.csv
# 2021-06-10 01:29:13,903 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC020_VCAP_24H.csv
# 2021-06-10 01:29:13,903 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC020_VCAP_24H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC020_VCAP_24H.csv
# 2021-06-10 01:29:13,905 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC020_VCAP_24H.csv
# 2021-06-10 01:29:13,905 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC020_VCAP_24H.csv
# INFO:root:BRD-A35108200inCPC006_NOMO1_6H.f
# 2021-06-10 01:29:15,947 - root - INFO - BRD-A35108200inCPC006_NOMO1_6H.f
# 2021-06-10 01:29:15,947 - root - INFO - BRD-A35108200inCPC006_NOMO1_6H.f
# INFO:root:BRD-A69951442inCPC006_NOMO1_6H.f
# 2021-06-10 01:29:19,837 - root - INFO - BRD-A69951442inCPC006_NOMO1_6H.f
# 2021-06-10 01:29:19,837 - root - INFO - BRD-A69951442inCPC006_NOMO1_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_NOMO1_6H.csv
# 2021-06-10 01:29:23,878 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_NOMO1_6H.csv
# 2021-06-10 01:29:23,878 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_NOMO1_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC006_NOMO1_6H.csv
# 2021-06-10 01:29:23,879 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_NOMO1_6H.csv
# 2021-06-10 01:29:23,879 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_NOMO1_6H.csv
# INFO:root:BRD-A35108200inCPC006_COV644_6H.f
# 2021-06-10 01:29:30,476 - root - INFO - BRD-A35108200inCPC006_COV644_6H.f
# 2021-06-10 01:29:30,476 - root - INFO - BRD-A35108200inCPC006_COV644_6H.f
# INFO:root:BRD-A69951442inCPC006_COV644_6H.f
# 2021-06-10 01:29:34,492 - root - INFO - BRD-A69951442inCPC006_COV644_6H.f
# 2021-06-10 01:29:34,492 - root - INFO - BRD-A69951442inCPC006_COV644_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_COV644_6H.csv
# 2021-06-10 01:29:38,602 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_COV644_6H.csv
# 2021-06-10 01:29:38,602 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_COV644_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC006_COV644_6H.csv
# 2021-06-10 01:29:38,603 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_COV644_6H.csv
# 2021-06-10 01:29:38,603 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_COV644_6H.csv
# INFO:root:BRD-A35108200inCPC006_SKLU1_6H.f
# 2021-06-10 01:29:41,427 - root - INFO - BRD-A35108200inCPC006_SKLU1_6H.f
# 2021-06-10 01:29:41,427 - root - INFO - BRD-A35108200inCPC006_SKLU1_6H.f
# INFO:root:BRD-A69951442inCPC006_SKLU1_6H.f
# 2021-06-10 01:29:46,162 - root - INFO - BRD-A69951442inCPC006_SKLU1_6H.f
# 2021-06-10 01:29:46,162 - root - INFO - BRD-A69951442inCPC006_SKLU1_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_SKLU1_6H.csv
# 2021-06-10 01:29:50,947 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_SKLU1_6H.csv
# 2021-06-10 01:29:50,947 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC006_SKLU1_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC006_SKLU1_6H.csv
# 2021-06-10 01:29:50,948 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_SKLU1_6H.csv
# 2021-06-10 01:29:50,948 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC006_SKLU1_6H.csv
# INFO:root:Passed: KHW001_SKM1_6H.f
# 2021-06-10 01:29:51,878 - root - INFO - Passed: KHW001_SKM1_6H.f
# 2021-06-10 01:29:51,878 - root - INFO - Passed: KHW001_SKM1_6H.f
# INFO:root:BRD-K38775274inCPC014_MCF7_6H.f
# 2021-06-10 01:30:03,112 - root - INFO - BRD-K38775274inCPC014_MCF7_6H.f
# 2021-06-10 01:30:03,112 - root - INFO - BRD-K38775274inCPC014_MCF7_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC014_MCF7_6H.csv
# 2021-06-10 01:30:39,134 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC014_MCF7_6H.csv
# 2021-06-10 01:30:39,134 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC014_MCF7_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC014_MCF7_6H.csv
# 2021-06-10 01:30:39,135 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC014_MCF7_6H.csv
# 2021-06-10 01:30:39,135 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC014_MCF7_6H.csv
# INFO:root:Passed: LJP004_BT20_24H.f
# 2021-06-10 01:30:46,338 - root - INFO - Passed: LJP004_BT20_24H.f
# 2021-06-10 01:30:46,338 - root - INFO - Passed: LJP004_BT20_24H.f
# INFO:root:BRD-K38775274inCPC014_VCAP_24H.f
# 2021-06-10 01:30:50,154 - root - INFO - BRD-K38775274inCPC014_VCAP_24H.f
# 2021-06-10 01:30:50,154 - root - INFO - BRD-K38775274inCPC014_VCAP_24H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC014_VCAP_24H.csv
# 2021-06-10 01:31:11,481 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC014_VCAP_24H.csv
# 2021-06-10 01:31:11,481 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC014_VCAP_24H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC014_VCAP_24H.csv
# 2021-06-10 01:31:11,483 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC014_VCAP_24H.csv
# 2021-06-10 01:31:11,483 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC014_VCAP_24H.csv
# INFO:root:BRD-A35108200inCPC009_HT29_6H.f
# 2021-06-10 01:31:13,227 - root - INFO - BRD-A35108200inCPC009_HT29_6H.f
# 2021-06-10 01:31:13,227 - root - INFO - BRD-A35108200inCPC009_HT29_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC009_HT29_6H.csv
# 2021-06-10 01:31:23,198 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC009_HT29_6H.csv
# 2021-06-10 01:31:23,198 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC009_HT29_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC009_HT29_6H.csv
# 2021-06-10 01:31:23,200 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC009_HT29_6H.csv
# 2021-06-10 01:31:23,200 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC009_HT29_6H.csv
# INFO:root:BRD-K38775274inCPC020_HA1E_6H.f
# 2021-06-10 01:31:25,111 - root - INFO - BRD-K38775274inCPC020_HA1E_6H.f
# 2021-06-10 01:31:25,111 - root - INFO - BRD-K38775274inCPC020_HA1E_6H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC020_HA1E_6H.csv
# 2021-06-10 01:31:35,140 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC020_HA1E_6H.csv
# 2021-06-10 01:31:35,140 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPC020_HA1E_6H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPC020_HA1E_6H.csv
# 2021-06-10 01:31:35,141 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC020_HA1E_6H.csv
# 2021-06-10 01:31:35,141 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPC020_HA1E_6H.csv
# INFO:root:Passed: LJP004_MCF10A_6H.f
# 2021-06-10 01:31:46,701 - root - INFO - Passed: LJP004_MCF10A_6H.f
# 2021-06-10 01:31:46,701 - root - INFO - Passed: LJP004_MCF10A_6H.f
# INFO:root:BRD-K00835182inCPD001_MCF7_24H.f
# 2021-06-10 01:31:47,576 - root - INFO - BRD-K00835182inCPD001_MCF7_24H.f
# 2021-06-10 01:31:47,576 - root - INFO - BRD-K00835182inCPD001_MCF7_24H.f
# INFO:root:BRD-K30207000inCPD001_MCF7_24H.f
# 2021-06-10 01:31:57,663 - root - INFO - BRD-K30207000inCPD001_MCF7_24H.f
# 2021-06-10 01:31:57,663 - root - INFO - BRD-K30207000inCPD001_MCF7_24H.f
# INFO:root:Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPD001_MCF7_24H.csv
# 2021-06-10 01:32:07,873 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPD001_MCF7_24H.csv
# 2021-06-10 01:32:07,873 - root - INFO - Saved!../data/dexamethasone_v2/predicted_rnaseq_signature_CPD001_MCF7_24H.csv
# INFO:root:Saved!../data/dexamethasone_v2/l1000_signature_CPD001_MCF7_24H.csv
# 2021-06-10 01:32:07,875 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPD001_MCF7_24H.csv
# 2021-06-10 01:32:07,875 - root - INFO - Saved!../data/dexamethasone_v2/l1000_signature_CPD001_MCF7_24H.csv

# %%
pool = multiprocessing.Pool(2)
batchfiles = os.listdir(pred_folder)

pool.map(chdir, batchfiles)
pool.close()
# Out:
# INFO:root:BRD-K38775274inCPC020_HCC515_6H.f
# 2021-06-10 00:24:55,426 - root - INFO - BRD-K38775274inCPC020_HCC515_6H.f
# 2021-06-10 00:24:55,426 - root - INFO - BRD-K38775274inCPC020_HCC515_6H.f
# INFO:root:BRD-A10188456inCPC004_VCAP_24H.f
# 2021-06-10 00:24:58,546 - root - INFO - BRD-A10188456inCPC004_VCAP_24H.f
# 2021-06-10 00:24:58,546 - root - INFO - BRD-A10188456inCPC004_VCAP_24H.f
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-490444308d53> in <module>
#       2 batchfiles = os.listdir(pred_folder)
#       3
# ----> 4 pool.map(chdir, batchfiles)
#       5 pool.close()
#
# ~/anaconda3/envs/python37/lib/python3.7/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     266         in a list that is returned.
#     267         '''
# --> 268         return self._map_async(func, iterable, mapstar, chunksize).get()
#     269
#     270     def starmap(self, func, iterable, chunksize=None):
#
# ~/anaconda3/envs/python37/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# ~/anaconda3/envs/python37/lib/python3.7/multiprocessing/pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# ~/anaconda3/envs/python37/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/anaconda3/envs/python37/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
l1000_signature_list = list()
predicted_rnaseq_signature_list = list()

exp_plates = dexamethasone_inst_info["exp_plate"].unique()
for exp_plate in exp_plates:
    print(exp_plate)
    filename = exp_plate+".f"
    pert_ids = dexamethasone_inst_info.loc[dexamethasone_inst_info["exp_plate"]==exp_plate,"pert_id"].unique()
    for pert_id in pert_ids:
        print(pert_id)
        l1000_data = load_feather(folder+filename, index=gene_list).loc[common_gene_list, :]
        predicted_rnaseq_data = load_feather(pred_folder+filename, index=None)[common_gene_list].T

        inst_info_batch = inst_info[inst_info["rna_plate"].str.startswith(exp_plate)]

        control_inst_ids = inst_info_batch.loc[inst_info_batch["pert_id"]==pert_id, "inst_id"].tolist()
        case_inst_ids = inst_info_batch.loc[inst_info_batch["pert_id"]!=pert_id, "inst_id"].tolist()

        # get signatures from real L1000 profiles
        l1000_signature = get_signatures(l1000_data[control_inst_ids], l1000_data[case_inst_ids])        
        l1000_signature = l1000_signature.rank(ascending=False)# values to rank
        l1000_signature_list.append(l1000_signature)

        # get signatures from predicted RNA-seq profiles
        predicted_rnaseq_signature = get_signatures(predicted_rnaseq_data[control_inst_ids], predicted_rnaseq_data[case_inst_ids])
        predicted_rnaseq_signature = predicted_rnaseq_signature.rank(ascending=False)
        predicted_rnaseq_signature_list.append(predicted_rnaseq_signature)
    break
# Out:
# CPC004_A375_6H
# BRD-A10188456
# BRD-K47635719

# %%
# concat
mean_l1000_signature = pd.concat(l1000_signature_list, axis=1).mean(axis=1)
mean_predicted_rnaseq_signature = pd.concat(predicted_rnaseq_signature_list, axis=1).mean(axis=1)

# %%
# bridge plot

# %% [markdown]
# # Compute Gene Signatures of Real L1000 Profiles

# %%
filenames = sorted(os.listdir(folder))

# %%
for filename in filenames:
    if filename.endswith(".f") == False:
        continue
    print(filename)
    data = load_feather(folder+filename, index=gene_list).loc[common_gene_list, :]
    inst_info_batch = inst_info[inst_info["rna_plate"].str.startswith(filename.replace(".f", ""))]
    pert_ids = sorted(inst_info_batch["pert_id"].unique())

    
    for pert_id in pert_ids:
        print(pert_id)
        control_inst_ids = inst_info_batch.loc[inst_info_batch["pert_id"]==pert_id, "inst_id"].tolist()
        case_inst_ids = inst_info_batch.loc[inst_info_batch["pert_id"]!=pert_id, "inst_id"].tolist()
        signature = get_signatures(data[control_inst_ids], data[case_inst_ids])
        break
    break
# Out:
# AML001_CD34_24H.f
# BRD-A03772856

# %% [markdown]
# # Compute Gene Signatures of Predicted RNA-seq Profiles

# %%
pred_filenames = sorted(os.listdir(pred_folder))

# %%
for filename in pred_filenames:
    if filename.endswith(".f") == False:
        continue
    print(pred_folder+filename)
    data = load_feather(pred_folder+filename, index=None)[common_gene_list].T
    
    inst_info_batch = inst_info[inst_info["rna_plate"].str.startswith(filename.replace(".f", ""))]
    pert_ids = sorted(inst_info_batch["pert_id"].unique())
    
    for pert_id in pert_ids:
        print(pert_id)
        control_inst_ids = inst_info_batch.loc[inst_info_batch["pert_id"]==pert_id, "inst_id"].tolist()
        case_inst_ids = inst_info_batch.loc[inst_info_batch["pert_id"]!=pert_id, "inst_id"].tolist()
        signature = get_signatures(data[control_inst_ids], data[case_inst_ids])
        break
    break
# Out:
# ../data/LINCS_CFDE/L1000_GSE92742_prediction_results_step2_batch_divided_38_35/AML001_CD34_24H.f
# BRD-A03772856
